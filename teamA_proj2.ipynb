# %%
#PROBLEM 2

# %%
import os
import binascii

def generate_random_key(length):
    """
    Generates a random key of the specified length.
    
    Args:
    - length (int): The length of the key to generate (should match the plaintext length).
    
    Returns:
    - bytes: A randomly generated key.
    """
    return os.urandom(length)

def xor_bytes(data, key):
    """
    Performs XOR between the data (plaintext) and the key.
    
    Args:
    - data (bytes): The data to be XORed (e.g., plaintext).
    - key (bytes): The key to XOR the data with.
    
    Returns:
    - bytes: The result of XORing the data and key.
    """
    return bytes([data[i] ^ key[i] for i in range(len(data))])

def alice_encrypt():
    """
    Prompts the user for a plaintext message, encrypts it using a one-time pad, and saves the 
    ciphertext and key in separate files. Also displays the key.
    """
    # Prompt user to enter a plaintext message
    plaintext = input("Enter the message (plaintext): ").encode('utf-8')

    # Generate a random key with the same length as the plaintext
    key = generate_random_key(len(plaintext))

    # Encrypt the plaintext by performing XOR with the key
    ciphertext = xor_bytes(plaintext, key)

    # Save the ciphertext and key to separate files (in hex format)
    with open('ciphertext.txt', 'w') as f:
        f.write(binascii.hexlify(ciphertext).decode('utf-8'))

    with open('key.txt', 'w') as f:
        f.write(binascii.hexlify(key).decode('utf-8'))

    # Display the ciphertext and key to the user in hex format
    print(f"Ciphertext (in hex): {binascii.hexlify(ciphertext).decode('utf-8')}")
    print(f"Key (in hex): {binascii.hexlify(key).decode('utf-8')}")
    print("Encryption complete! Ciphertext and key saved to files.")

# Run the encryption process for Alice
alice_encrypt()
# Out:
# Ciphertext (in hex): cf226d9ce9a797ad6ef57d
# Key (in hex): a74701f08687e0c21c9919
# Encryption complete! Ciphertext and key saved to files.

# %%
import binascii

def xor_bytes(data, key):
    """
    Performs XOR between the data (ciphertext) and the key.
    
    Args:
    - data (bytes): The data to be XORed (e.g., ciphertext).
    - key (bytes): The key to XOR the data with.
    
    Returns:
    - bytes: The result of XORing the data and key.
    """
    return bytes([data[i] ^ key[i] for i in range(len(data))])

def bob_decrypt():
    """
    Reads the key and ciphertext from files, decrypts the ciphertext using the one-time pad 
    key, and displays the original plaintext. Also displays the key.
    """
    try:
        # Read the ciphertext from the file (in hex format)
        with open('ciphertext.txt', 'r') as f:
            ciphertext_hex = f.read()
            ciphertext = binascii.unhexlify(ciphertext_hex)

        # Read the key from the file (in hex format)
        with open('key.txt', 'r') as f:
            key_hex = f.read()
            key = binascii.unhexlify(key_hex)

        # Decrypt the ciphertext by XORing it with the key
        plaintext = xor_bytes(ciphertext, key)

        # Display the original decrypted message (plaintext) and the key
        print(f"Decrypted message (plaintext): {plaintext.decode('utf-8')}")
        print(f"Key used (in hex): {binascii.hexlify(key).decode('utf-8')}")

    except FileNotFoundError:
        print("Error: Ciphertext or key file not found. Make sure both files are present.")

# Run the decryption process for Bob
bob_decrypt()
# Out:
# Decrypted message (plaintext): hello world
# Key used (in hex): a74701f08687e0c21c9919

# %%
#PROBLEM 3

# %%
#PROBLEM 3
import os
import binascii

def generate_random_key(length):
    #Generates a random key of the specified length.
    return os.urandom(length)

def xor_bytes(data, key):
    #Performs XOR between the data (plaintext) and the key, handling cases where key might be shorter than data.
    return bytes([a ^ b for a, b in zip(data, key * (len(data) // len(key) + 1))])

def encrypt_many_time_pad():
    #Encrypts multiple messages with the same key and saves results.
    messages = [
        "I love pizza",
        "I need a job asap",
        "Five in the morning",
        "Attack at dawn",
        "Blood dont flow",
        "Black Labs are great",
        "We dont deserve dogs",
        "Sit up straight",
        "Democracy is fragile",
        "Ancient Apocalypse"
    ]

    # Generate a key. Here, we'll manually set a length or you can dynamically set based on the longest message
    key_length = max(len(msg.encode('utf-8')) for msg in messages)
    key = generate_random_key(key_length)

    results = []
    for i, msg in enumerate(messages, 1):
        plaintext = msg.encode('utf-8')
        ciphertext = xor_bytes(plaintext, key)
        results.append({
            'Message': msg,
            'Plain Hex': binascii.hexlify(plaintext).decode('utf-8'),
            'Cipher Hex': binascii.hexlify(ciphertext).decode('utf-8'),
            'Key Hex': binascii.hexlify(key).decode('utf-8')
        })

    # Save all results to a file
    with open('many_time_pad_encryption.txt', 'w') as f:
        for entry in results:
            f.write(f"Message {results.index(entry) + 1}:\n")
            f.write(f"Plaintext: {entry['Message']}\n")
            f.write(f"Plaintext (hex): {entry['Plain Hex']}\n")
            f.write(f"Ciphertext (hex): {entry['Cipher Hex']}\n")
            f.write(f"Key (hex): {entry['Key Hex']}\n\n")

    print("Encryption complete. Results saved to 'many_time_pad_encryption.txt'.")

# Run the many-time pad encryption process
encrypt_many_time_pad()
# Out:
# Encryption complete. Results saved to 'many_time_pad_encryption.txt'.

# %%
#PROBLEM 4

# %%
# Given ciphertexts
ciphertexts = [
"71fe1ace4389087266117cd7c98c4182851b3acff3b086e3f83f94d6eb05c4ba85d8e1fa14f11d1c3b568ff6cff5c09c5d67ef5c9c71b7eeb3d45a5154ab17b83e071ce9d8988adb4afedf46a840",  "71fe1ace559a1e7266117cd7ce8745d7be2e74c3f0f68eeef57e8884e607debf81dfa0f012f95819681ae7f29fe4839b5175ef5e8760bef0b9d44b504eba12b22f5404f89dd085d550a48865a14f9b15a94dabe609ca2df2cccf210cefdb1af5389719795e1f0179cb77c5c456954d88f3",
    # More ciphertexts truncated for brevity
"71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"
]
# Convert hex strings to byte arrays
ciphertexts_bytes = [bytes.fromhex(c) for c in ciphertexts]
# XOR two ciphertexts
def xor_bytes(b1, b2):
    return bytes([a ^ b for a, b in zip(b1, b2)])
# XOR all ciphertext pairs
for i in range(len(ciphertexts_bytes)):
    for j in range(i + 1, len(ciphertexts_bytes)):
        xor_result = xor_bytes(ciphertexts_bytes[i], ciphertexts_bytes[j])
        print(f"XOR of Ciphertext {i+1} and Ciphertext {j+1}: {xor_result.hex()}")
# Now manually inspect the results and apply crib dragging to guess known English patterns
# Out:
# XOR of Ciphertext 1 and Ciphertext 2: 000000001613160000000000070b04553b354e0c0346080d0d411c520d021a050407410a06084505534c6804501143070c1200021b11091e0a0011011a11050a1153181145480f0e1a5a5723090f
# XOR of Ciphertext 1 and Ciphertext 3: 00001c4e571400491a0f45414e1603522c354d4f050f190b0c134c4e0d19160249011209490e0d011f4b2d1c000c0c110c441106150f4c03174311
# XOR of Ciphertext 2 and Ciphertext 3: 00001c4e410716491a0f4541491d070717000343064911060152501c001b0c074d0653034f0648044c074518501d4f16005611040e1e451d1d4300

# %%
# Given ciphertexts
ciphertexts = [
    "71fe1ace4389087266117cd7c98c4182851b3acff3b086e3f83f94d6eb05c4ba85d8e1fa14f11d1c3b568ff6cff5c09c5d67ef5c9c71b7eeb3d45a5154ab17b83e071ce9d8988adb4afedf46a840",
    "71fe1ace559a1e7266117cd7ce8745d7be2e74c3f0f68eeef57e8884e607debf81dfa0f012f95819681ae7f29fe4839b5175ef5e8760bef0b9d44b504eba12b22f5404f89dd085d550a48865a14f9b15a94dabe609ca2df2cccf210cefdb1af5389719795e1f0179cb77c5c456954d88f3",
    "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"
]

# Convert hex strings to byte arrays
ciphertexts_bytes = [bytes.fromhex(c) for c in ciphertexts]

# XOR two ciphertexts
def xor_bytes(b1, b2):
    return bytes([a ^ b for a, b in zip(b1, b2)])

# Store XOR results
xor_results = []

# XOR all ciphertext pairs
for i in range(len(ciphertexts_bytes)):
    for j in range(i + 1, len(ciphertexts_bytes)):
        xor_result = xor_bytes(ciphertexts_bytes[i], ciphertexts_bytes[j])
        xor_results.append(xor_result)

# Define the known plaintext (crib)
crib = b"Hello"

def xor_with_crib(xor_result, crib):
    crib_length = len(crib)
    for start in range(len(xor_result) - crib_length + 1):
        segment = xor_result[start:start + crib_length]
        guessed_plaintext = bytes(a ^ b for a, b in zip(segment, crib))
        print(f"Segment: {segment.hex()} | Guessed Plaintext: {guessed_plaintext.decode(errors='ignore')}")

# Analyze each XOR result with the crib
for i, result in enumerate(xor_results):
    print(f"Analyzing XOR Result {i + 1}: {result.hex()}")
    xor_with_crib(result, crib)
# Out:
# Analyzing XOR Result 1: 000000001613160000000000070b04553b354e0c0346080d0d411c520d021a050407410a06084505534c6804501143070c1200021b11091e0a0011011a11050a1153181145480f0e1a5a5723090f
# Segment: 0000000016 | Guessed Plaintext: Helly
# Segment: 0000001613 | Guessed Plaintext: Helz|
# Segment: 0000161316 | Guessed Plaintext: Hezy
# Segment: 0016131600 | Guessed Plaintext: Hszo
# Segment: 1613160000 | Guessed Plaintext: ^vzlo
# Segment: 1316000000 | Guessed Plaintext: [sllo
# Segment: 1600000000 | Guessed Plaintext: ^ello
# Segment: 0000000000 | Guessed Plaintext: Hello
# Segment: 0000000007 | Guessed Plaintext: Hellh
# Segment: 000000070b | Guessed Plaintext: Helkd
# Segment: 0000070b04 | Guessed Plaintext: Hekgk
# Segment: 00070b0455 | Guessed Plaintext: Hbgh:
# Segment: 070b04553b | Guessed Plaintext: Onh9T
# Segment: 0b04553b35 | Guessed Plaintext: Ca9WZ
# Segment: 04553b354e | Guessed Plaintext: L0WY!
# Segment: 553b354e0c | Guessed Plaintext:
# ^Y"c
# Segment: 3b354e0c03 | Guessed Plaintext: sP"`l
# Segment: 354e0c0346 | Guessed Plaintext: }+`o)
# Segment: 4e0c034608 | Guessed Plaintext: io*g
# Segment: 0c0346080d | Guessed Plaintext: Df*db
# Segment: 0346080d0d | Guessed Plaintext: K#dab
# Segment: 46080d0d41 | Guessed Plaintext: maa.
# Segment: 080d0d411c | Guessed Plaintext: @ha-s
# Segment: 0d0d411c52 | Guessed Plaintext: Eh-p=
# Segment: 0d411c520d | Guessed Plaintext: E$p>b
# Segment: 411c520d02 | Guessed Plaintext: 	y>am
# Segment: 1c520d021a | Guessed Plaintext: T7anu
# Segment: 520d021a05 | Guessed Plaintext: hnvj
# Segment: 0d021a0504 | Guessed Plaintext: Egvik
# Segment: 021a050407 | Guessed Plaintext: Jihh
# Segment: 1a05040741 | Guessed Plaintext: R`hk.
# Segment: 050407410a | Guessed Plaintext: Mak-e
# Segment: 0407410a06 | Guessed Plaintext: Lb-fi
# Segment: 07410a0608 | Guessed Plaintext: O$fjg
# Segment: 410a060845 | Guessed Plaintext: 	ojd*
# Segment: 0a06084505 | Guessed Plaintext: Bcd)j
# Segment: 0608450553 | Guessed Plaintext: Nm)i<
# Segment: 084505534c | Guessed Plaintext: @ i?#
# `? ent: 4505534c68 | Guessed Plaintext:
# Segment: 05534c6804 | Guessed Plaintext: M6 k
# Segment: 534c680450 | Guessed Plaintext: )h?
# h<~ment: 4c68045011 | Guessed Plaintext:
# Segment: 6804501143 | Guessed Plaintext:  a<},
# Segment: 0450114307 | Guessed Plaintext: L5}/h
# Segment: 501143070c | Guessed Plaintext: t/kc
# Segment: 1143070c12 | Guessed Plaintext: Y&k`}
# Segment: 43070c1200 | Guessed Plaintext:
# b`~o
# Segment: 070c120002 | Guessed Plaintext: Oi~lm
# Segment: 0c1200021b | Guessed Plaintext: Dwlnt
# Segment: 1200021b11 | Guessed Plaintext: Zenw~
# Segment: 00021b1109 | Guessed Plaintext: Hgw}f
# Segment: 021b11091e | Guessed Plaintext: J~}eq
# Segment: 1b11091e0a | Guessed Plaintext: Stere
# Segment: 11091e0a00 | Guessed Plaintext: Ylrfo
# Segment: 091e0a0011 | Guessed Plaintext: A{fl~
# Segment: 1e0a001101 | Guessed Plaintext: Vol}n
# Segment: 0a0011011a | Guessed Plaintext: Be}mu
# Segment: 0011011a11 | Guessed Plaintext: Htmv~
# Segment: 11011a1105 | Guessed Plaintext: Ydv}j
# Segment: 011a11050a | Guessed Plaintext: I}ie
# Segment: 1a11050a11 | Guessed Plaintext: Rtif~
# Segment: 11050a1153 | Guessed Plaintext: Y`f}<
# Segment: 050a115318 | Guessed Plaintext: Mo}?w
# Segment: 0a11531811 | Guessed Plaintext: Bt?t~
# Segment: 1153181145 | Guessed Plaintext: Y6t}*
# Segment: 5318114548 | Guessed Plaintext: }})'
# Segment: 181145480f | Guessed Plaintext: Pt)$`
# Segment: 1145480f0e | Guessed Plaintext: Y $ca
# -cbuent: 45480f0e1a | Guessed Plaintext:
# Segment: 480f0e1a5a | Guessed Plaintext: jbv5
# Segment: 0f0e1a5a57 | Guessed Plaintext: Gkv68
# Segment: 0e1a5a5723 | Guessed Plaintext: F6;L
# Segment: 1a5a572309 | Guessed Plaintext: R?;Of
# Segment: 5a5723090f | Guessed Plaintext: 2Oe`
# Analyzing XOR Result 2: 00001c4e571400491a0f45414e1603522c354d4f050f190b0c134c4e0d19160249011209490e0d011f4b2d1c000c0c110c441106150f4c03174311
# Segment: 00001c4e57 | Guessed Plaintext: Hep"8
# Segment: 001c4e5714 | Guessed Plaintext: Hy";{
# Segment: 1c4e571400 | Guessed Plaintext: T+;xo
# Segment: 4e57140049 | Guessed Plaintext: 2xl&
# Segment: 571400491a | Guessed Plaintext: ql%u
# Segment: 1400491a0f | Guessed Plaintext: \e%v`
# Segment: 00491a0f45 | Guessed Plaintext: H,vc*
# Segment: 491a0f4541 | Guessed Plaintext: c).
# Segment: 1a0f45414e | Guessed Plaintext: Rj)-!
# Segment: 0f45414e16 | Guessed Plaintext: G -"y
# $"zlent: 45414e1603 | Guessed Plaintext:
# Segment: 414e160352 | Guessed Plaintext: 	+zo=
# Segment: 4e1603522c | Guessed Plaintext: so>C
# Segment: 1603522c35 | Guessed Plaintext: ^f>@Z
# Segment: 03522c354d | Guessed Plaintext: K7@Y"
# Segment: 522c354d4f | Guessed Plaintext: IY!
# Segment: 2c354d4f05 | Guessed Plaintext: dP!#j
# Segment: 354d4f050f | Guessed Plaintext: }(#i`
# Segment: 4d4f050f19 | Guessed Plaintext: *icv
# Segment: 4f050f190b | Guessed Plaintext: `cud
# Segment: 050f190b0c | Guessed Plaintext: Mjugc
# Segment: 0f190b0c13 | Guessed Plaintext: G|g`|
# Segment: 190b0c134c | Guessed Plaintext: Qn`#
# Segment: 0b0c134c4e | Guessed Plaintext: Ci !
# Segment: 0c134c4e0d | Guessed Plaintext: Dv "b
# Segment: 134c4e0d19 | Guessed Plaintext: [)"av
# Segment: 4c4e0d1916 | Guessed Plaintext: +auy
# Segment: 4e0d191602 | Guessed Plaintext: huzm
# Segment: 0d19160249 | Guessed Plaintext: E|zn&
# Segment: 1916024901 | Guessed Plaintext: Qsn%n
# Segment: 1602490112 | Guessed Plaintext: ^g%m}
# Segment: 0249011209 | Guessed Plaintext: J,m~f
# Segment: 4901120949 | Guessed Plaintext: d~e&
# Segment: 011209490e | Guessed Plaintext: Iwe%a
# Segment: 1209490e0d | Guessed Plaintext: Zl%bb
# Segment: 09490e0d01 | Guessed Plaintext: A,ban
# Segment: 490e0d011f | Guessed Plaintext: kamp
# Segment: 0e0d011f4b | Guessed Plaintext: Fhms$
# Segment: 0d011f4b2d | Guessed Plaintext: Eds'B
# Segment: 011f4b2d1c | Guessed Plaintext: Iz'As
# Segment: 1f4b2d1c00 | Guessed Plaintext: W.Apo
# Segment: 4b2d1c000c | Guessed Plaintext: Hplc
# Segment: 2d1c000c0c | Guessed Plaintext: eyl`c
# Segment: 1c000c0c11 | Guessed Plaintext: Te``~
# Segment: 000c0c110c | Guessed Plaintext: Hi`}c
# Segment: 0c0c110c44 | Guessed Plaintext: Di}`+
# Segment: 0c110c4411 | Guessed Plaintext: Dt`(~
# Segment: 110c441106 | Guessed Plaintext: Yi(}i
# Segment: 0c44110615 | Guessed Plaintext: D!}jz
# Segment: 441106150f | Guessed Plaintext:
# tjy`
# Segment: 1106150f4c | Guessed Plaintext: Ycyc#
# Segment: 06150f4c03 | Guessed Plaintext: Npc l
# Segment: 150f4c0317 | Guessed Plaintext: ]j ox
# Segment: 0f4c031743 | Guessed Plaintext: G)o{,
# Segment: 4c03174311 | Guessed Plaintext: f{/~
# Analyzing XOR Result 3: 00001c4e410716491a0f4541491d070717000343064911060152501c001b0c074d0653034f0648044c074518501d4f16005611040e1e451d1d4300
# Segment: 00001c4e41 | Guessed Plaintext: Hep".
# Segment: 001c4e4107 | Guessed Plaintext: Hy"-h
# Segment: 1c4e410716 | Guessed Plaintext: T+-ky
# Segment: 4e41071649 | Guessed Plaintext: $kz&
# Segment: 410716491a | Guessed Plaintext: 	bz%u
# Segment: 0716491a0f | Guessed Plaintext: Os%v`
# Segment: 16491a0f45 | Guessed Plaintext: ^,vc*
# Segment: 491a0f4541 | Guessed Plaintext: c).
# Segment: 1a0f454149 | Guessed Plaintext: Rj)-&
# Segment: 0f4541491d | Guessed Plaintext: G -%r
# $%qhent: 4541491d07 | Guessed Plaintext:
# Segment: 41491d0707 | Guessed Plaintext: 	,qkh
# Segment: 491d070717 | Guessed Plaintext: xkkx
# Segment: 1d07071700 | Guessed Plaintext: Ubk{o
# Segment: 0707170003 | Guessed Plaintext: Ob{ll
# Segment: 0717000343 | Guessed Plaintext: Orlo,
# Segment: 1700034306 | Guessed Plaintext: _eo/i
# Segment: 0003430649 | Guessed Plaintext: Hf/j&
# Segment: 0343064911 | Guessed Plaintext: K&j%~
# Segment: 4306491106 | Guessed Plaintext:
# c%}i
# Segment: 0649110601 | Guessed Plaintext: N,}jn
# Segment: 4911060152 | Guessed Plaintext: tjm=
# Segment: 1106015250 | Guessed Plaintext: Ycm>?
# Segment: 060152501c | Guessed Plaintext: Nd><s
# Segment: 0152501c00 | Guessed Plaintext: I7<po
# Segment: 52501c001b | Guessed Plaintext: 5plt
# Segment: 501c001b0c | Guessed Plaintext: ylwc
# Segment: 1c001b0c07 | Guessed Plaintext: Tew`h
# Segment: 001b0c074d | Guessed Plaintext: H~`k"
# Segment: 1b0c074d06 | Guessed Plaintext: Sik!i
# Segment: 0c074d0653 | Guessed Plaintext: Db!j<
# Segment: 074d065303 | Guessed Plaintext: O(j?l
# Segment: 4d0653034f | Guessed Plaintext: c?o
# Segment: 0653034f06 | Guessed Plaintext: N6o#i
# Segment: 53034f0648 | Guessed Plaintext: f#j'
# Segment: 034f064804 | Guessed Plaintext: K*j$k
# Segment: 4f0648044c | Guessed Plaintext: c$h#
# Segment: 0648044c07 | Guessed Plaintext: N-h h
# Segment: 48044c0745 | Guessed Plaintext: a k*
# Segment: 044c074518 | Guessed Plaintext: L)k)w
# Segment: 4c07451850 | Guessed Plaintext: b)t?
# Segment: 074518501d | Guessed Plaintext: O t<r
# }<q ent: 4518501d4f | Guessed Plaintext:
# Segment: 18501d4f16 | Guessed Plaintext: P5q#y
# Segment: 501d4f1600 | Guessed Plaintext: x#zo
# Segment: 1d4f160056 | Guessed Plaintext: U*zl9
# Segment: 4f16005611 | Guessed Plaintext: sl:~
# Segment: 1600561104 | Guessed Plaintext: ^e:}k
# Segment: 005611040e | Guessed Plaintext: H3}ha
# Segment: 5611040e1e | Guessed Plaintext:
# thbq
# Segment: 11040e1e45 | Guessed Plaintext: Yabr*
# Segment: 040e1e451d | Guessed Plaintext: Lkr)r
# Segment: 0e1e451d1d | Guessed Plaintext: F{)qr
# Segment: 1e451d1d43 | Guessed Plaintext: V qq,
# xq/oent: 451d1d4300 | Guessed Plaintext:

# %%
from collections import Counter

# Example XOR result as bytes (replace this with actual byte values)
xor_result = b'\x1d\x00\x00\x72\x5f\xa0\x52\x02\x3d\x0f\x0d\x45\xcf\x54\xc1\x2c\x5b\x0b\x5b\x25\x02\xd6\x88\x7e\x85\xc7\x2f\xf1\xf1\xc5\xbc\x8d\x4c\xbd\x05\xb5\xc5\x2f'

def frequency_analysis(data):
    """Analyze the frequency of bytes in the given data."""
    return Counter(data).most_common(10)

# Perform frequency analysis
freq = frequency_analysis(xor_result)
print(f"Frequency Analysis for XOR Result: {freq}")
# Out:
# Frequency Analysis for XOR Result: [(0, 2), (2, 2), (91, 2), (47, 2), (241, 2), (197, 2), (29, 1), (114, 1), (95, 1), (160, 1)]

# %%
def xor_with_crib(ciphertext, crib):
    """XOR the ciphertext with a known crib and check for valid output."""
    crib_length = len(crib)
    for start in range(len(ciphertext) - crib_length + 1):
        segment = ciphertext[start:start + crib_length]
        decrypted_segment = bytes(a ^ b for a, b in zip(segment, crib))
        try:
            print(f"Segment starting at {start}: {decrypted_segment.decode()} (with crib: {crib})")
        except UnicodeDecodeError:
            continue  # Skip any errors in decoding

# Example ciphertext and crib
ciphertext = b'\x1d\x00\x00\x72\x5f\xa0\x52\x02\x3d\x0f\x0d\x45\xcf\x54\xc1\x2c\x5b\x0b\x5b\x25\x02\xd6\x88\x7e\x85\xc7\x2f\xf1\xf1\xc5\xbc\x8d\x4c\xbd\x05\xb5\xc5\x2f'
crib = b"Hello"  # Modify as needed
xor_with_crib(ciphertext, crib)
# Out:
# Segment starting at 0: Uel
# 0 (with crib: b'Hello')
# Segment starting at 6: gQcb (with crib: b'Hello')
# Segment starting at 7: JXca* (with crib: b'Hello')
# Segment starting at 15: d>g7J (with crib: b'Hello')
# Segment starting at 16: n7Im (with crib: b'Hello')
